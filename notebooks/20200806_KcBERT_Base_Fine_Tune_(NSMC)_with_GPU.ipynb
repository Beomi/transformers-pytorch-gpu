# %% [markdown]
# # Package 설치 & 데이터 받기

# %%
# !pip install -q transformers pytorch_lightning emoji soynlp

# %%
# !git clone https://github.com/e9t/nsmc
# Out:
# Cloning into 'nsmc'...
# remote: Enumerating objects: 14763, done.
# remote: Total 14763 (delta 0), reused 0 (delta 0), pack-reused 14763
# Receiving objects: 100% (14763/14763), 56.19 MiB | 11.88 MiB/s, done.
# Resolving deltas: 100% (1749/1749), done.
# Checking out files: 100% (14737/14737), done.

# %%
# !head nsmc/ratings_train.txt
# Out:
# id	document	label
# 9976970	아 더빙.. 진짜 짜증나네요 목소리	0
# 3819312	흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나	1
# 10265843	너무재밓었다그래서보는것을추천한다	0
# 9045019	교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정	0
# 6483659	사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 던스트가 너무나도 이뻐보였다	1
# 5403919	막 걸음마 뗀 3세부터 초등학교 1학년생인 8살용영화.ㅋㅋㅋ...별반개도 아까움.	0
# 7797314	원작의 긴장감을 제대로 살려내지못했다.	0
# 9443947	별 반개도 아깝다 욕나온다 이응경 길용우 연기생활이몇년인지..정말 발로해도 그것보단 낫겟다 납치.감금만반복반복..이드라마는 가족도없다 연기못하는사람만모엿네	0
# 7156791	액션이 없는데도 재미 있는 몇안되는 영화	1

# %% [markdown]
# # 패키지 import & 기본 Args 설정

# %%
import os
import pandas as pd

from pprint import pprint

import torch
from torch.utils.data import Dataset, DataLoader, TensorDataset
from torch.optim.lr_scheduler import ExponentialLR

from pytorch_lightning import LightningModule, Trainer, seed_everything

from transformers import BertForSequenceClassification, BertTokenizer, AdamW

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

import re
import emoji
from soynlp.normalizer import repeat_normalize

# %% [markdown]
# ## 기본 학습 Arguments

# %%
class Arg:
    random_seed: int = 42  # Random Seed
    pretrained_model: str = 'beomi/kcbert-base'  # Transformers PLM name
    pretrained_tokenizer: str = ''  # Optional, Transformers Tokenizer Name. Overrides `pretrained_model`
    auto_batch_size: str = 'power'  # Let PyTorch Lightening find the best batch size 
    batch_size: int = 0  # Optional, Train/Eval Batch Size. Overrides `auto_batch_size` 
    lr: float = 5e-6  # Starting Learning Rate
    epochs: int = 20  # Max Epochs
    max_length: int = 150  # Max Length input size
    report_cycle: int = 100  # Report (Train Metrics) Cycle
    train_data_path: str = "nsmc/ratings_train.txt"  # Train Dataset file 
    val_data_path: str = "nsmc/ratings_test.txt"  # Validation Dataset file 
    cpu_workers: int = os.cpu_count()  # Multi cpu workers
    test_mode: bool = False  # Test Mode enables `fast_dev_run`
    optimizer: str = 'AdamW'  # AdamW vs AdamP
    lr_scheduler: str = 'exp'  # ExponentialLR vs CosineAnnealingWarmRestarts
    fp16: bool = False  # Enable train on FP16
    tpu_cores: int = 0  # Enable TPU with 1 core or 8 cores

args = Arg()

# %% [markdown]
# ## 기본값을 Override 하고싶은 경우 아래와 같이 수정

# %%
# args.tpu_cores = 8  # Enables TPU
args.fp16 = True  # Enables GPU FP16
args.batch_size = 16  # Force setup batch_size

# %%
class Model(LightningModule):
    def __init__(self, options):
        super().__init__()
        self.args = options
        self.bert = BertForSequenceClassification.from_pretrained(self.args.pretrained_model)
        self.tokenizer = BertTokenizer.from_pretrained(
            self.args.pretrained_tokenizer
            if self.args.pretrained_tokenizer
            else self.args.pretrained_model
        )

    def forward(self, **kwargs):
        return self.bert(**kwargs)

    def training_step(self, batch, batch_idx):
        data, labels = batch
        loss, logits = self(input_ids=data, labels=labels)
        preds = logits.argmax(dim=-1)

        y_true = labels.cpu().numpy()
        y_pred = preds.cpu().numpy()

        # Acc, Precision, Recall, F1
        metrics = [
            metric(y_true=y_true, y_pred=y_pred)
            for metric in
            (accuracy_score, precision_score, recall_score, f1_score)
        ]

        tensorboard_logs = {
            'train_loss': loss.cpu().detach().numpy().tolist(),
            'train_acc': metrics[0],
            'train_precision': metrics[1],
            'train_recall': metrics[2],
            'train_f1': metrics[3],
        }
        if (batch_idx % self.args.report_cycle) == 0:
            print()
            pprint(tensorboard_logs)
        return {'loss': loss, 'log': tensorboard_logs}

    def validation_step(self, batch, batch_idx):
        data, labels = batch
        loss, logits = self(input_ids=data, labels=labels)
        preds = logits.argmax(dim=-1)

        y_true = list(labels.cpu().numpy())
        y_pred = list(preds.cpu().numpy())

        return {
            'loss': loss,
            'y_true': y_true,
            'y_pred': y_pred,
        }

    def validation_epoch_end(self, outputs):
        loss = torch.tensor(0, dtype=torch.float)
        for i in outputs:
            loss += i['loss'].cpu().detach()
        _loss = loss / len(outputs)

        loss = float(_loss)
        y_true = []
        y_pred = []

        for i in outputs:
            y_true += i['y_true']
            y_pred += i['y_pred']

        # Acc, Precision, Recall, F1
        metrics = [
            metric(y_true=y_true, y_pred=y_pred)
            for metric in
            (accuracy_score, precision_score, recall_score, f1_score)
        ]

        tensorboard_logs = {
            'val_loss': loss,
            'val_acc': metrics[0],
            'val_precision': metrics[1],
            'val_recall': metrics[2],
            'val_f1': metrics[3],
        }

        print()
        pprint(tensorboard_logs)
        return {'loss': _loss, 'log': tensorboard_logs}

    def configure_optimizers(self):
        if self.args.optimizer == 'AdamW':
            optimizer = AdamW(self.parameters(), lr=self.args.lr)
        elif self.args.optimizer == 'AdamP':
            from adamp import AdamP
            optimizer = AdamP(self.parameters(), lr=self.args.lr)
        else:
            raise NotImplementedError('Only AdamW and AdamP is Supported!')
        if self.args.lr_scheduler == 'cos':
            scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=1, T_mult=2)
        elif self.args.lr_scheduler == 'exp':
            scheduler = ExponentialLR(optimizer, gamma=0.5)
        else:
            raise NotImplementedError('Only cos and exp lr scheduler is Supported!')
        return {
            'optimizer': optimizer,
            'scheduler': scheduler,
        }

    def read_data(self, path):
        if path.endswith('xlsx'):
            return pd.read_excel(path)
        elif path.endswith('csv'):
            return pd.read_csv(path)
        elif path.endswith('tsv') or path.endswith('txt'):
            return pd.read_csv(path, sep='\t')
        else:
            raise NotImplementedError('Only Excel(xlsx)/Csv/Tsv(txt) are Supported')

    def preprocess_dataframe(self, df):
        emojis = ''.join(emoji.UNICODE_EMOJI.keys())
        pattern = re.compile(f'[^ .,?!/@$%~％·∼()\x00-\x7Fㄱ-힣{emojis}]+')
        url_pattern = re.compile(
            r'https?:\/\/(www\.)?[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)')

        def clean(x):
            x = pattern.sub(' ', x)
            x = url_pattern.sub('', x)
            x = x.strip()
            x = repeat_normalize(x, num_repeats=2)
            return x

        df['document'] = df['document'].map(lambda x: self.tokenizer.encode(
            clean(str(x)),
            padding='max_length',
            max_length=self.args.max_length,
            truncation=True,
        ))
        return df

    def train_dataloader(self):
        df = self.read_data(self.args.train_data_path)
        df = self.preprocess_dataframe(df)

        dataset = TensorDataset(
            torch.tensor(df['document'].to_list(), dtype=torch.long),
            torch.tensor(df['label'].to_list(), dtype=torch.long),
        )
        return DataLoader(
            dataset,
            batch_size=self.args.batch_size or self.batch_size,
            shuffle=True,
            num_workers=self.args.cpu_workers,
        )

    def val_dataloader(self):
        df = self.read_data(self.args.val_data_path)
        df = self.preprocess_dataframe(df)

        dataset = TensorDataset(
            torch.tensor(df['document'].to_list(), dtype=torch.long),
            torch.tensor(df['label'].to_list(), dtype=torch.long),
        )
        return DataLoader(
            dataset,
            batch_size=self.args.batch_size or self.batch_size,
            shuffle=False,
            num_workers=self.args.cpu_workers,
        )

# %%
def main():
    print("Using PyTorch Ver", torch.__version__)
    print("Fix Seed:", args.random_seed)
    seed_everything(args.random_seed)
    model = Model(args)

    print(":: Start Training ::")
    trainer = Trainer(
        max_epochs=args.epochs,
        fast_dev_run=args.test_mode,
        num_sanity_val_steps=None if args.test_mode else 0,
        auto_scale_batch_size=args.auto_batch_size if args.auto_batch_size and not args.batch_size else False,
        # For GPU Setup
        deterministic=torch.cuda.is_available(),
        gpus=1 if torch.cuda.is_available() else None,
        precision=16 if args.fp16 else 32,
        # For TPU Setup
        tpu_cores=args.tpu_cores if args.tpu_cores else None,
    )
    trainer.fit(model)

# %% [markdown]
# # 학습!
#
# > 주의: 1epoch별로 GPU-P100기준 약 2~3시간, GPU V100기준 ~40분이 걸립니다.
#
# > Update @ 2020.09.01
# > 최근 Colab Pro에서 V100이 배정됩니다.
#
# ```python
# # 1epoch 기준 아래 score가 나옵니다.
# {'val_acc': 0.90522,
#  'val_f1': 0.9049023739289227,
#  'val_loss': 0.23429009318351746,
#  'val_precision': 0.9143146796431468,
#  'val_recall': 0.8956818813808446}
# ```

# %%
main()
# Out:
# Using PyTorch Ver 1.6.0+cu101
# Fix Seed: 42
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=619.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=438218004.0, style=ProgressStyle(descri…
# Some weights of the model checkpoint at beomi/kcbert-base were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at beomi/kcbert-base and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=249928.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=49.0, style=ProgressStyle(description_w…
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# CUDA_VISIBLE_DEVICES: [0]
# Using native 16bit precision.
# :: Start Training ::
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:37: UserWarning: Could not log computational graph since the `model.example_input_array` attribute is not set or `input_array` was not given
#   warnings.warn(*args, **kwargs)
#
#   | Name | Type                          | Params
# -------------------------------------------------------
# 0 | bert | BertForSequenceClassification | 108 M
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# {'train_acc': 0.3125,
#  'train_f1': 0.47619047619047616,
#  'train_loss': 0.9376538991928101,
#  'train_precision': 0.3125,
#  'train_recall': 1.0}
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'train_acc': 0.5625,
#  'train_f1': 0.588235294117647,
#  'train_loss': 0.7111761569976807,
#  'train_precision': 0.7142857142857143,
#  'train_recall': 0.5}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.7272727272727273,
#  'train_loss': 0.5922739505767822,
#  'train_precision': 1.0,
#  'train_recall': 0.5714285714285714}
#
# {'train_acc': 0.75,
#  'train_f1': 0.7777777777777777,
#  'train_loss': 0.5431863069534302,
#  'train_precision': 0.7,
#  'train_recall': 0.875}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8571428571428571,
#  'train_loss': 0.38144007325172424,
#  'train_precision': 1.0,
#  'train_recall': 0.75}
#
# {'train_acc': 0.875,
#  'train_f1': 0.875,
#  'train_loss': 0.30336084961891174,
#  'train_precision': 0.875,
#  'train_recall': 0.875}
#
# {'train_acc': 0.875,
#  'train_f1': 0.7499999999999999,
#  'train_loss': 0.27870360016822815,
#  'train_precision': 1.0,
#  'train_recall': 0.6}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.19521617889404297,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9523809523809523,
#  'train_loss': 0.30710461735725403,
#  'train_precision': 1.0,
#  'train_recall': 0.9090909090909091}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.7272727272727272,
#  'train_loss': 0.5430271029472351,
#  'train_precision': 0.8,
#  'train_recall': 0.6666666666666666}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.14956752955913544,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.8235294117647058,
#  'train_loss': 0.42051583528518677,
#  'train_precision': 0.7,
#  'train_recall': 1.0}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.6666666666666666,
#  'train_loss': 0.4433272182941437,
#  'train_precision': 0.5,
#  'train_recall': 1.0}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8750000000000001,
#  'train_loss': 0.2805574834346771,
#  'train_precision': 0.7777777777777778,
#  'train_recall': 1.0}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8333333333333333,
#  'train_loss': 0.2513520121574402,
#  'train_precision': 0.7142857142857143,
#  'train_recall': 1.0}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8333333333333334,
#  'train_loss': 0.390297532081604,
#  'train_precision': 0.8333333333333334,
#  'train_recall': 0.8333333333333334}
#
# {'train_acc': 0.875,
#  'train_f1': 0.9166666666666666,
#  'train_loss': 0.28217941522598267,
#  'train_precision': 0.9166666666666666,
#  'train_recall': 0.9166666666666666}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.8,
#  'train_loss': 0.6329561471939087,
#  'train_precision': 0.6666666666666666,
#  'train_recall': 1.0}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.8571428571428572,
#  'train_loss': 0.6379237771034241,
#  'train_precision': 0.9,
#  'train_recall': 0.8181818181818182}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.8,
#  'train_loss': 0.450053334236145,
#  'train_precision': 1.0,
#  'train_recall': 0.6666666666666666}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8888888888888888,
#  'train_loss': 0.2964252233505249,
#  'train_precision': 0.8888888888888888,
#  'train_recall': 0.8888888888888888}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.8571428571428571,
#  'train_loss': 0.13800399005413055,
#  'train_precision': 1.0,
#  'train_recall': 0.75}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8571428571428571,
#  'train_loss': 0.34123221039772034,
#  'train_precision': 0.8571428571428571,
#  'train_recall': 0.8571428571428571}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9333333333333333,
#  'train_loss': 0.16439443826675415,
#  'train_precision': 1.0,
#  'train_recall': 0.875}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9333333333333333,
#  'train_loss': 0.11289425939321518,
#  'train_precision': 1.0,
#  'train_recall': 0.875}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.8,
#  'train_loss': 0.3089224398136139,
#  'train_precision': 1.0,
#  'train_recall': 0.6666666666666666}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.18148331344127655,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.625,
#  'train_f1': 0.625,
#  'train_loss': 0.5402029156684875,
#  'train_precision': 0.625,
#  'train_recall': 0.625}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8333333333333333,
#  'train_loss': 0.2986210584640503,
#  'train_precision': 1.0,
#  'train_recall': 0.7142857142857143}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.1449219435453415,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8333333333333334,
#  'train_loss': 0.38031524419784546,
#  'train_precision': 0.8333333333333334,
#  'train_recall': 0.8333333333333334}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.8235294117647058,
#  'train_loss': 0.4428020715713501,
#  'train_precision': 1.0,
#  'train_recall': 0.7}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.6666666666666666,
#  'train_loss': 0.37324345111846924,
#  'train_precision': 0.5,
#  'train_recall': 1.0}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9523809523809523,
#  'train_loss': 0.1871166229248047,
#  'train_precision': 1.0,
#  'train_recall': 0.9090909090909091}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.7692307692307693,
#  'train_loss': 0.4073370099067688,
#  'train_precision': 0.625,
#  'train_recall': 1.0}
#
# {'train_acc': 0.875,
#  'train_f1': 0.9,
#  'train_loss': 0.2341545820236206,
#  'train_precision': 0.8181818181818182,
#  'train_recall': 1.0}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.823529411764706,
#  'train_loss': 0.2779534161090851,
#  'train_precision': 0.875,
#  'train_recall': 0.7777777777777778}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9333333333333333,
#  'train_loss': 0.21313261985778809,
#  'train_precision': 0.875,
#  'train_recall': 1.0}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8888888888888888,
#  'train_loss': 0.26379820704460144,
#  'train_precision': 0.8888888888888888,
#  'train_recall': 0.8888888888888888}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.8,
#  'train_loss': 0.33421507477760315,
#  'train_precision': 0.6666666666666666,
#  'train_recall': 1.0}
#
# {'train_acc': 0.875,
#  'train_f1': 0.9,
#  'train_loss': 0.2787189483642578,
#  'train_precision': 1.0,
#  'train_recall': 0.8181818181818182}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9333333333333333,
#  'train_loss': 0.37789344787597656,
#  'train_precision': 1.0,
#  'train_recall': 0.875}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.09651783108711243,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.8235294117647058,
#  'train_loss': 0.40621933341026306,
#  'train_precision': 0.7,
#  'train_recall': 1.0}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9411764705882353,
#  'train_loss': 0.2090000957250595,
#  'train_precision': 1.0,
#  'train_recall': 0.8888888888888888}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.823529411764706,
#  'train_loss': 0.3164721727371216,
#  'train_precision': 0.7777777777777778,
#  'train_recall': 0.875}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9523809523809523,
#  'train_loss': 0.19987305998802185,
#  'train_precision': 1.0,
#  'train_recall': 0.9090909090909091}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.07490342855453491,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8333333333333334,
#  'train_loss': 0.2277032434940338,
#  'train_precision': 0.8333333333333334,
#  'train_recall': 0.8333333333333334}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.923076923076923,
#  'train_loss': 0.13712865114212036,
#  'train_precision': 1.0,
#  'train_recall': 0.8571428571428571}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9411764705882353,
#  'train_loss': 0.28926631808280945,
#  'train_precision': 1.0,
#  'train_recall': 0.8888888888888888}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.923076923076923,
#  'train_loss': 0.17685610055923462,
#  'train_precision': 0.8571428571428571,
#  'train_recall': 1.0}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.7272727272727272,
#  'train_loss': 0.3465372920036316,
#  'train_precision': 0.6666666666666666,
#  'train_recall': 0.8}
#
# {'train_acc': 0.875,
#  'train_f1': 0.888888888888889,
#  'train_loss': 0.26995569467544556,
#  'train_precision': 0.8,
#  'train_recall': 1.0}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9090909090909091,
#  'train_loss': 0.298768550157547,
#  'train_precision': 0.8333333333333334,
#  'train_recall': 1.0}
#
# {'train_acc': 0.6875,
#  'train_f1': 0.5454545454545454,
#  'train_loss': 0.5277204513549805,
#  'train_precision': 0.6,
#  'train_recall': 0.5}
#
# {'train_acc': 0.75,
#  'train_f1': 0.6666666666666666,
#  'train_loss': 0.337916761636734,
#  'train_precision': 0.6666666666666666,
#  'train_recall': 0.6666666666666666}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8750000000000001,
#  'train_loss': 0.3751504719257355,
#  'train_precision': 1.0,
#  'train_recall': 0.7777777777777778}
# {'train_acc': 0.9375,
#  'train_f1': 0.9333333333333333,
#  'train_loss': 0.1803649365901947,
#  'train_precision': 1.0,
#  'train_recall': 0.875}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8333333333333333,
#  'train_loss': 0.3298461437225342,
#  'train_precision': 1.0,
#  'train_recall': 0.7142857142857143}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.10055308043956757,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.15662772953510284,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.8421052631578948,
#  'train_loss': 0.337302565574646,
#  'train_precision': 0.8,
#  'train_recall': 0.8888888888888888}
#
# {'train_acc': 0.75,
#  'train_f1': 0.7142857142857143,
#  'train_loss': 0.61372971534729,
#  'train_precision': 0.625,
#  'train_recall': 0.8333333333333334}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.09569765627384186,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8571428571428571,
#  'train_loss': 0.2796337902545929,
#  'train_precision': 1.0,
#  'train_recall': 0.75}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9333333333333333,
#  'train_loss': 0.1433326154947281,
#  'train_precision': 1.0,
#  'train_recall': 0.875}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.923076923076923,
#  'train_loss': 0.25540703535079956,
#  'train_precision': 1.0,
#  'train_recall': 0.8571428571428571}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.7272727272727272,
#  'train_loss': 0.31267648935317993,
#  'train_precision': 0.6666666666666666,
#  'train_recall': 0.8}
#
# {'train_acc': 0.875,
#  'train_f1': 0.9,
#  'train_loss': 0.39827436208724976,
#  'train_precision': 1.0,
#  'train_recall': 0.8181818181818182}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8888888888888888,
#  'train_loss': 0.22382041811943054,
#  'train_precision': 0.8888888888888888,
#  'train_recall': 0.8888888888888888}
#
# {'train_acc': 0.6875,
#  'train_f1': 0.761904761904762,
#  'train_loss': 0.4087687134742737,
#  'train_precision': 0.8,
#  'train_recall': 0.7272727272727273}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9473684210526316,
#  'train_loss': 0.16771914064884186,
#  'train_precision': 0.9,
#  'train_recall': 1.0}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.8571428571428572,
#  'train_loss': 0.324521005153656,
#  'train_precision': 0.8181818181818182,
#  'train_recall': 0.9}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.8421052631578948,
#  'train_loss': 0.480808824300766,
#  'train_precision': 0.8888888888888888,
#  'train_recall': 0.8}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.923076923076923,
#  'train_loss': 0.1997477114200592,
#  'train_precision': 0.8571428571428571,
#  'train_recall': 1.0}
#
# {'train_acc': 0.6875,
#  'train_f1': 0.6153846153846153,
#  'train_loss': 0.6391028761863708,
#  'train_precision': 0.5714285714285714,
#  'train_recall': 0.6666666666666666}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.0459400974214077,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.923076923076923,
#  'train_loss': 0.22079916298389435,
#  'train_precision': 1.0,
#  'train_recall': 0.8571428571428571}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8571428571428571,
#  'train_loss': 0.21680663526058197,
#  'train_precision': 0.8571428571428571,
#  'train_recall': 0.8571428571428571}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8333333333333334,
#  'train_loss': 0.38512709736824036,
#  'train_precision': 0.8333333333333334,
#  'train_recall': 0.8333333333333334}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9411764705882353,
#  'train_loss': 0.3648967146873474,
#  'train_precision': 0.8888888888888888,
#  'train_recall': 1.0}
#
# {'train_acc': 0.75,
#  'train_f1': 0.7142857142857143,
#  'train_loss': 0.4338186979293823,
#  'train_precision': 0.5555555555555556,
#  'train_recall': 1.0}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8571428571428571,
#  'train_loss': 0.30900508165359497,
#  'train_precision': 0.8571428571428571,
#  'train_recall': 0.8571428571428571}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.923076923076923,
#  'train_loss': 0.16104979813098907,
#  'train_precision': 1.0,
#  'train_recall': 0.8571428571428571}
#
# {'train_acc': 0.875,
#  'train_f1': 0.9,
#  'train_loss': 0.3052418529987335,
#  'train_precision': 0.8181818181818182,
#  'train_recall': 1.0}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.080571748316288,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.7999999999999999,
#  'train_loss': 0.4211167097091675,
#  'train_precision': 0.75,
#  'train_recall': 0.8571428571428571}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.11620645970106125,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9090909090909091,
#  'train_loss': 0.2166261225938797,
#  'train_precision': 1.0,
#  'train_recall': 0.8333333333333334}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9523809523809523,
#  'train_loss': 0.1570696234703064,
#  'train_precision': 1.0,
#  'train_recall': 0.9090909090909091}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.7272727272727272,
#  'train_loss': 0.2777244448661804,
#  'train_precision': 0.6666666666666666,
#  'train_recall': 0.8}
#
# {'train_acc': 0.875,
#  'train_f1': 0.875,
#  'train_loss': 0.16533534228801727,
#  'train_precision': 0.875,
#  'train_recall': 0.875}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.823529411764706,
#  'train_loss': 0.2860371172428131,
#  'train_precision': 0.875,
#  'train_recall': 0.7777777777777778}
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# {'val_acc': 0.89316,
#  'val_f1': 0.8952055869428751,
#  'val_loss': 0.2580045759677887,
#  'val_precision': 0.8842770220516994,
#  'val_recall': 0.906407658999722}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9090909090909091,
#  'train_loss': 0.3283892869949341,
#  'train_precision': 0.8333333333333334,
#  'train_recall': 1.0}
#
# {'train_acc': 0.875,
#  'train_f1': 0.875,
#  'train_loss': 0.26096311211586,
#  'train_precision': 0.875,
#  'train_recall': 0.875}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9333333333333333,
#  'train_loss': 0.10614607483148575,
#  'train_precision': 1.0,
#  'train_recall': 0.875}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.05443572625517845,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.875,
#  'train_f1': 0.875,
#  'train_loss': 0.22787487506866455,
#  'train_precision': 0.875,
#  'train_recall': 0.875}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.06423278152942657,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.04634501412510872,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9333333333333333,
#  'train_loss': 0.14314910769462585,
#  'train_precision': 1.0,
#  'train_recall': 0.875}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9473684210526316,
#  'train_loss': 0.1452164351940155,
#  'train_precision': 0.9,
#  'train_recall': 1.0}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.07807143032550812,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9565217391304348,
#  'train_loss': 0.2366185188293457,
#  'train_precision': 0.9166666666666666,
#  'train_recall': 1.0}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.7999999999999999,
#  'train_loss': 0.26323774456977844,
#  'train_precision': 0.8571428571428571,
#  'train_recall': 0.75}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8750000000000001,
#  'train_loss': 0.2266593724489212,
#  'train_precision': 1.0,
#  'train_recall': 0.7777777777777778}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8333333333333334,
#  'train_loss': 0.3410886526107788,
#  'train_precision': 0.8333333333333334,
#  'train_recall': 0.8333333333333334}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8,
#  'train_loss': 0.3076714873313904,
#  'train_precision': 0.6666666666666666,
#  'train_recall': 1.0}
#
# {'train_acc': 0.75,
#  'train_f1': 0.8181818181818181,
#  'train_loss': 0.47690916061401367,
#  'train_precision': 1.0,
#  'train_recall': 0.6923076923076923}
#
# {'train_acc': 0.875,
#  'train_f1': 0.888888888888889,
#  'train_loss': 0.24298106133937836,
#  'train_precision': 1.0,
#  'train_recall': 0.8}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.13022494316101074,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.875,
#  'train_f1': 0.888888888888889,
#  'train_loss': 0.25252851843833923,
#  'train_precision': 1.0,
#  'train_recall': 0.8}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8571428571428571,
#  'train_loss': 0.36552122235298157,
#  'train_precision': 0.75,
#  'train_recall': 1.0}
#
# {'train_acc': 0.75,
#  'train_f1': 0.75,
#  'train_loss': 0.3904258906841278,
#  'train_precision': 0.6666666666666666,
#  'train_recall': 0.8571428571428571}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.07617776095867157,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9411764705882353,
#  'train_loss': 0.10077613592147827,
#  'train_precision': 1.0,
#  'train_recall': 0.8888888888888888}
#
# {'train_acc': 0.875,
#  'train_f1': 0.888888888888889,
#  'train_loss': 0.6082579493522644,
#  'train_precision': 0.8,
#  'train_recall': 1.0}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.888888888888889,
#  'train_loss': 0.1250910460948944,
#  'train_precision': 1.0,
#  'train_recall': 0.8}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.923076923076923,
#  'train_loss': 0.1097397431731224,
#  'train_precision': 0.8571428571428571,
#  'train_recall': 1.0}
#
# {'train_acc': 0.75,
#  'train_f1': 0.8333333333333334,
#  'train_loss': 0.4107950031757355,
#  'train_precision': 0.8333333333333334,
#  'train_recall': 0.8333333333333334}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.8,
#  'train_loss': 0.31472986936569214,
#  'train_precision': 0.6666666666666666,
#  'train_recall': 1.0}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9090909090909091,
#  'train_loss': 0.27570071816444397,
#  'train_precision': 0.8333333333333334,
#  'train_recall': 1.0}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9411764705882353,
#  'train_loss': 0.11290115863084793,
#  'train_precision': 0.8888888888888888,
#  'train_recall': 1.0}
#
# {'train_acc': 0.875,
#  'train_f1': 0.888888888888889,
#  'train_loss': 0.29537951946258545,
#  'train_precision': 1.0,
#  'train_recall': 0.8}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.7999999999999999,
#  'train_loss': 0.35153964161872864,
#  'train_precision': 0.75,
#  'train_recall': 0.8571428571428571}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8333333333333333,
#  'train_loss': 0.3053549826145172,
#  'train_precision': 0.7142857142857143,
#  'train_recall': 1.0}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9090909090909091,
#  'train_loss': 0.09322921931743622,
#  'train_precision': 1.0,
#  'train_recall': 0.8333333333333334}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9523809523809523,
#  'train_loss': 0.17958882451057434,
#  'train_precision': 0.9090909090909091,
#  'train_recall': 1.0}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9473684210526316,
#  'train_loss': 0.21586595475673676,
#  'train_precision': 0.9,
#  'train_recall': 1.0}
#
# {'train_acc': 0.75,
#  'train_f1': 0.6666666666666666,
#  'train_loss': 0.3932528495788574,
#  'train_precision': 0.8,
#  'train_recall': 0.5714285714285714}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9333333333333333,
#  'train_loss': 0.17451077699661255,
#  'train_precision': 0.875,
#  'train_recall': 1.0}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9473684210526316,
#  'train_loss': 0.18300031125545502,
#  'train_precision': 1.0,
#  'train_recall': 0.9}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9333333333333333,
#  'train_loss': 0.13174140453338623,
#  'train_precision': 0.875,
#  'train_recall': 1.0}
#
# {'train_acc': 0.875,
#  'train_f1': 0.9090909090909091,
#  'train_loss': 0.2290610522031784,
#  'train_precision': 0.9090909090909091,
#  'train_recall': 0.9090909090909091}
